# %% [markdown]
# # Setup
# This IPython notebook will walk through the steps of characterizing iModulons through the semi-automated tools in PyModulon. You will need:
#
# * M and A matrices
# * Expression data (e.g. `log_tpm_norm.csv`)
# * Gene table and KEGG/GO annotations (Generated in `gene_annotation.ipynb`)
# * Sample table, with a column for `project` and `condition`
# * TRN file
#
# Optional:
# * iModulon table (if you already have some characterized iModulons)

# %%
from pymodulon.core import IcaData
from pymodulon.plotting import *
from os import path
import pandas as pd
import re
from Bio.KEGG import REST
from tqdm.notebook import tqdm

# %%
# Enter the location of your data here
data_dir = path.join('..','data')

# GO and KEGG annotations are in the 'external' folder
external_data = path.join('..','data')

# %% [markdown]
# ## Check your sample table (i.e. metadata file)
# Your metadata file will probably have a lot of columns, most of which you may not care about. Feel free to save a secondary copy of your metadata file with only columns that seem relevant to you. The two most important columns are:
# 1. `project`
# 2. `condition`
#
# Make sure that these columns exist in your metadata file

# %%
df_metadata = pd.read_csv(os.path.join('..','data','metadata.tsv',index_col=0,sep='\t'))
df_metadata[['project','condition']].head()
# Out:
#                     project          condition
# Experiment
# ERX1862757             sigD                 WT
# ERX1862758             sigD           DEL-sigD
# ERX1862759             sigD        pVWEx1-sigD
# ERX1862760             sigD   pVWEx1-sigD-IPTG
# ERX2442263  altering-oxygen  JL-3h-2-Stuttgart

# %%
print(df_metadata.project.notnull().all())
print(df_metadata.condition.notnull().all())
# Out:
# False
# False

# %% [markdown]
# ## Check your TRN

# %% [markdown]
# Each row of the TRN file represents a regulatory interaction.
# **Your TRN file must have the following columns:**
# 1. `regulator` - Name of regulator (`/` or `+` characters will be converted to `;`)
# 1. `gene_id` - Locus tag of gene being regulated
#
# The following columns are optional, but are helpful to have:
# 1. `regulator_id` - Locus tag of regulator
# 1. `gene_name` - Name of gene (can automatically update this using `name2num`)
# 1. `direction` - Direction of regulation ('+' for activation, '-' for repression, '?' or NaN for unknown)
# 1. `evidence` - Evidence of regulation (e.g. ChIP-exo, qRT-PCR, SELEX, Motif search)
# 1. `PMID` - Reference for regulation
#
# You may add any other columns that could help you. TRNs may be saved as either CSV or TSV files. See below for an example:

# %%
df_trn = pd.read_csv(os.path.join('..','data','TRN.csv'))
df_trn.head()
# Out:
#      regulator      gene_id
# 0  WA5_RS00045  WA5_RS06090
# 1  WA5_RS00045  WA5_RS06085
# 2  WA5_RS00045  WA5_RS06080
# 3  WA5_RS00045  WA5_RS06075
# 4  WA5_RS00045  WA5_RS05065

# %% [markdown]
# The `regulator` and `gene_id` must be filled in for each row

# %%
print(df_trn.regulator.notnull().all())
print(df_trn.gene_id.notnull().all())
# Out:
# True
# True

# %% [markdown]
# ## Load the data
# You're now ready to load your IcaData object!

# %%
df_mapping = pd.read_excel(os.path.join('..','data','MM_2ldfeeem.emapper.annotations.xlsx'))
df_trn['regulator_locus_tag']=''
df_trn['gene_id_locus_tag']=''
dict = {}
for row in df_mapping.index:
    maps = {df_mapping.loc[row]['seed_ortholog'].split(".")[1]:df_mapping.loc[row]['query']}
    dict.update(maps)
for row in df_trn.index:
    df_trn.loc[row]['regulator_locus_tag'] = dict.get(df_trn.loc[row]['regulator'])
    df_trn.loc[row]['gene_id_locus_tag'] = dict.get(df_trn.loc[row]['gene_id'])
df_trn.to_excel(r"E:\test\trn_test.xlsx")

# %%
data = pd.read_excel(os.path.join('..','data','TRN.xlsx',index_col=0))
data.to_csv(os.path.join('..','data','TRN.xlsx',encoding='utf-8'))

# %%
ica_data = IcaData(M = path.join(data_dir,'M.csv'),
                   A = path.join(data_dir,'A.csv'),
                   X = path.join(data_dir,'log_tpm_test.csv'),
                   gene_table = path.join(data_dir,'gene_info.csv'),
                   sample_table = path.join(data_dir,'metadata_test.tsv'),
                   trn = path.join(data_dir,'trn_atlas.csv'),
                   optimize_cutoff=True)
# Out:
# WARNING:root:Optimizing iModulon thresholds, may take 2-3 minutes...

# %% [markdown]
# If you don't have a TRN (or have a very minimal TRN), use `threshold_method = 'kmeans'`

# %%
ica_data = IcaData(M = path.join(data_dir1,'M.csv'),
                   A = path.join(data_dir1,'A.csv'),
                   X = path.join(data_dir1,'log_tpm_norm.csv'),
                   gene_table = path.join(data_dir1,'gene_info.csv'),
                   sample_table = path.join(data_dir1,'metadata.tsv'),
                   trn = path.join(data_dir1,'trn_atlas.csv'),
                   optimize_cutoff=True)
#                    threshold_method = 'kmeans'

# %% [markdown]
# # Regulatory iModulons
# Use `compute_trn_enrichment` to automatically check for Regulatory iModulons. The more complete your TRN, the more regulatory iModulons you'll find.

# %%
ica_data.compute_trn_enrichment()
# Out:
#     imodulon    regulator        pvalue        qvalue  precision    recall  \
# 0          2  WA5_RS04335  6.285513e-22  5.656962e-21   0.483871  0.384615
# 1          2  WA5_RS00460  1.739544e-09  7.827947e-09   0.161290  0.714286
# 2          9  WA5_RS14715  4.494476e-07  8.539504e-06   0.160000  0.177778
# 3         13  WA5_RS09565  1.036594e-13  1.036594e-12   0.300000  0.211268
# 4         15  WA5_RS11920  1.462165e-09  1.023516e-08   0.363636  0.666667
# 5         15  WA5_RS11905  4.771253e-08  1.669939e-07   0.363636  0.333333
# 6         15  WA5_RS11985  3.043188e-06  7.100772e-06   0.272727  0.333333
# 7         16  WA5_RS00825  6.207284e-18  6.207284e-17   0.384615  0.588235
# 8         19  WA5_RS13100  2.153334e-07  1.507334e-06   0.157895  1.000000
# 9         26  WA5_RS03145  1.580327e-10  5.057046e-09   0.043956  1.000000
# 10        26  WA5_RS14715  1.760484e-07  2.816775e-06   0.076923  0.311111
# 11        29  WA5_RS05330  8.884442e-09  2.665333e-08   0.600000  0.750000
# 12        29  WA5_RS01470  2.657335e-07  3.986002e-07   0.600000  0.300000
# 13        36  WA5_RS11355  6.190132e-13  3.714079e-12   0.428571  0.600000
# 14        37  WA5_RS07815  6.229139e-14  3.737484e-13   0.833333  0.714286
# 15        37  WA5_RS15475  1.292416e-11  3.877247e-11   0.833333  0.312500
# 16        37  WA5_RS09590  7.778732e-11  1.555746e-10   0.833333  0.227273
# 17        37  WA5_RS09565  3.793251e-08  5.689876e-08   0.833333  0.070423
# 18        37  WA5_RS01525  2.010019e-07  2.412022e-07   1.000000  0.025862
# 19        37  WA5_RS03810  1.107836e-06  1.107836e-06   0.833333  0.036232
# 20        42  WA5_RS00045  1.425296e-16  7.126479e-16   0.538462  0.777778
# 21        42  WA5_RS14715  1.686083e-10  4.215208e-10   0.538462  0.155556
# 22        43  WA5_RS14470  2.190839e-16  8.763356e-16   0.583333  0.700000
# 23        43  WA5_RS06975  8.370884e-13  1.674177e-12   0.500000  0.500000
# 24        44  WA5_RS02795  1.390581e-07  2.224930e-06   0.098039  0.555556
# 25        48  WA5_RS01340  2.657335e-07  7.972005e-07   0.600000  0.300000
# 26        48  WA5_RS09590  3.389768e-06  5.084652e-06   0.600000  0.136364
# 27        54  WA5_RS00605  4.333799e-07  3.033659e-06   0.375000  0.428571
#
#      f1score    TP  regulon_size  imodulon_size  n_regs
# 0   0.428571  15.0          39.0           31.0     1.0
# 1   0.263158   5.0           7.0           31.0     1.0
# 2   0.168421   8.0          45.0           50.0     1.0
# 3   0.247934  15.0          71.0           50.0     1.0
# 4   0.470588   4.0           6.0           11.0     1.0
# 5   0.347826   4.0          12.0           11.0     1.0
# 6   0.300000   3.0           9.0           11.0     1.0
# 7   0.465116  10.0          17.0           26.0     1.0
# 8   0.272727   3.0           3.0           19.0     1.0
# 9   0.084211   8.0           8.0          182.0     1.0
# 10  0.123348  14.0          45.0          182.0     1.0
# 11  0.666667   3.0           4.0            5.0     1.0
# 12  0.400000   3.0          10.0            5.0     1.0
# 13  0.500000   6.0          10.0           14.0     1.0
# 14  0.769231   5.0           7.0            6.0     1.0
# 15  0.454545   5.0          16.0            6.0     1.0
# 16  0.357143   5.0          22.0            6.0     1.0
# 17  0.129870   5.0          71.0            6.0     1.0
# 18  0.050420   6.0         232.0            6.0     1.0
# 19  0.069444   5.0         138.0            6.0     1.0
# 20  0.636364   7.0           9.0           13.0     1.0
# 21  0.241379   7.0          45.0           13.0     1.0
# 22  0.636364   7.0          10.0           12.0     1.0
# 23  0.500000   6.0          12.0           12.0     1.0
# 24  0.166667   5.0           9.0           51.0     1.0
# 25  0.400000   3.0          10.0            5.0     1.0
# 26  0.222222   3.0          22.0            5.0     1.0
# 27  0.400000   3.0           7.0            8.0     1.0

# %% [markdown]
# You can also search for AND/OR combinations of regulators using the `max_regs` argument.
#
# Regulator enrichments can be directly saved to the `imodulon_table` using the `save` argument. This saves the enrichment with the lowest q-value to the table.

# %%
# First search for regulator enrichments with 2 regulators
ica_data.compute_trn_enrichment(max_regs=2,save=True)

# Next, search for regulator enrichments with just one regulator. This will supercede the 2 regulator enrichments.
ica_data.compute_trn_enrichment(max_regs=1,save=True)
# Out:
#     imodulon    regulator        pvalue        qvalue  precision    recall  \
# 0          2  WA5_RS04335  6.285513e-22  5.656962e-21   0.483871  0.384615
# 1          2  WA5_RS00460  1.739544e-09  7.827947e-09   0.161290  0.714286
# 2          9  WA5_RS14715  4.494476e-07  8.539504e-06   0.160000  0.177778
# 3         13  WA5_RS09565  1.036594e-13  1.036594e-12   0.300000  0.211268
# 4         15  WA5_RS11920  1.462165e-09  1.023516e-08   0.363636  0.666667
# 23  0.500000   6.0          12.0           12.0     1.0
# 24  0.166667   5.0           9.0           51.0     1.0
# 25  0.400000   3.0          10.0            5.0     1.0
# 26  0.222222   3.0          22.0            5.0     1.0
# 27  0.400000   3.0           7.0            8.0     1.0

# %% [markdown]
# The list of regulatory iModulons are shown below

# %%
regulatory_imodulons = ica_data.imodulon_table[ica_data.imodulon_table.regulator.notnull()]
print(len(ica_data.imodulon_table),'Total iModulons')
print(len(regulatory_imodulons),'Regulatory iModulons')
regulatory_imodulons
# Out:
# 56 Total iModulons
# 15 Regulatory iModulons
#       regulator        pvalue        qvalue  precision    recall   f1score  \
# 2   WA5_RS04335  6.285513e-22  5.656962e-21   0.483871  0.384615  0.428571
# 9   WA5_RS14715  4.494476e-07  8.539504e-06   0.160000  0.177778  0.168421
# 13  WA5_RS09565  1.036594e-13  1.036594e-12   0.300000  0.211268  0.247934
# 15  WA5_RS11920  1.462165e-09  1.023516e-08   0.363636  0.666667  0.470588
# 16  WA5_RS00825  6.207284e-18  6.207284e-17   0.384615  0.588235  0.465116
# 19  WA5_RS13100  2.153334e-07  1.507334e-06   0.157895  1.000000  0.272727
# 26  WA5_RS03145  1.580327e-10  5.057046e-09   0.043956  1.000000  0.084211
# 29  WA5_RS05330  8.884442e-09  2.665333e-08   0.600000  0.750000  0.666667
# 36  WA5_RS11355  6.190132e-13  3.714079e-12   0.428571  0.600000  0.500000
# 37  WA5_RS07815  6.229139e-14  3.737484e-13   0.833333  0.714286  0.769231
# 42  WA5_RS00045  1.425296e-16  7.126479e-16   0.538462  0.777778  0.636364
# 43  WA5_RS14470  2.190839e-16  8.763356e-16   0.583333  0.700000  0.636364
# 44  WA5_RS02795  1.390581e-07  2.224930e-06   0.098039  0.555556  0.166667
# 48  WA5_RS01340  2.657335e-07  7.972005e-07   0.600000  0.300000  0.400000
# 54  WA5_RS00605  4.333799e-07  3.033659e-06   0.375000  0.428571  0.400000
#
#       TP  regulon_size  imodulon_size  n_regs
# 2   15.0          39.0           31.0     1.0
# 9    8.0          45.0           50.0     1.0
# 13  15.0          71.0           50.0     1.0
# 15   4.0           6.0           11.0     1.0
# 16  10.0          17.0           26.0     1.0
# 19   3.0           3.0           19.0     1.0
# 26   8.0           8.0          182.0     1.0
# 29   3.0           4.0            5.0     1.0
# 36   6.0          10.0           14.0     1.0
# 37   5.0           7.0            6.0     1.0
# 42   7.0           9.0           13.0     1.0
# 43   7.0          10.0           12.0     1.0
# 44   5.0           9.0           51.0     1.0
# 48   3.0          10.0            5.0     1.0
# 54   3.0           7.0            8.0     1.0

# %% [markdown]
# You can rename iModulons in this jupyter notebook, or you can save the iModulon table as a CSV and edit it in Excel.
#
# If two iModulons have the same regulator (e.g. 'Reg'), they will be named 'Reg-1' and 'Reg-2'

# %%
ica_data.rename_imodulons(regulatory_imodulons.regulator.to_dict())
ica_data.imodulon_table.head()
# Out:
#                regulator        pvalue        qvalue  precision    recall  \
# 0                    NaN           NaN           NaN        NaN       NaN
# 1                    NaN           NaN           NaN        NaN       NaN
# WA5_RS04335  WA5_RS04335  6.285513e-22  5.656962e-21   0.483871  0.384615
# 3                    NaN           NaN           NaN        NaN       NaN
# 4                    NaN           NaN           NaN        NaN       NaN
#
#               f1score    TP  regulon_size  imodulon_size  n_regs
# 0                 NaN   NaN           NaN            NaN     NaN
# 1                 NaN   NaN           NaN            NaN     NaN
# WA5_RS04335  0.428571  15.0          39.0           31.0     1.0
# 3                 NaN   NaN           NaN            NaN     NaN
# 4                 NaN   NaN           NaN            NaN     NaN

# %%
regulatory_imodulons = ica_data.imodulon_table[ica_data.imodulon_table.regulator.notnull()]

# %% [markdown]
# # Functional iModulons

# %% [markdown]
# GO annotations and KEGG pathways/modules were generated in the 1_create_the_gene_table.ipynb notebook. Enrichments will be calculated in this notebook, and further curated in the 3_manual_iModulon_curation notebook.

# %% [markdown]
# ## GO Enrichments

# %% [markdown]
# First load the Gene Ontology annotations

# %%
DF_GO = pd.read_csv(os.path.join('..','data','GO_annotations_curated.csv'),index_col=0)
DF_GO.head()
# Out:
#        gene_id gene_name                                      gene_ontology
# 0  WA5_RS07925       gap  glyceraldehyde-3-phosphate dehydrogenase (NAD+...
# 1  WA5_RS07925       gap                                        NAD binding
# 2  WA5_RS09740      recA                                       SOS response
# 3  WA5_RS05070      glpX                              magnesium ion binding
# 4  WA5_RS05070      glpX                              manganese ion binding

# %%
DF_GO_enrich = ica_data.compute_annotation_enrichment(DF_GO,'gene_ontology')

# %%
DF_GO_enrich
# Out:
#       imodulon                                      gene_ontology    pvalue  \
# 0           21                                        NAD binding  0.006998
# 1           21  glyceraldehyde-3-phosphate dehydrogenase (NAD+...  0.006998
# 2  WA5_RS00045   fructose 1,6-bisphosphate 1-phosphatase activity  0.004332
# 3  WA5_RS00045        fructose 1,6-bisphosphate metabolic process  0.004332
# 4  WA5_RS00045                                    gluconeogenesis  0.004332
# 5  WA5_RS00045                              manganese ion binding  0.004332
# 6  WA5_RS00045                              magnesium ion binding  0.008646
#
#      qvalue  precision  recall   f1score   TP  target_set_size  imodulon_size
# 0  0.073476   0.047619     1.0  0.090909  1.0              1.0           21.0
# 1  0.073476   0.047619     1.0  0.090909  1.0              1.0           21.0
# 2  0.022742   0.076923     1.0  0.142857  1.0              1.0           13.0
# 3  0.022742   0.076923     1.0  0.142857  1.0              1.0           13.0
# 4  0.022742   0.076923     1.0  0.142857  1.0              1.0           13.0
# 5  0.022742   0.076923     1.0  0.142857  1.0              1.0           13.0
# 6  0.036315   0.076923     0.5  0.133333  1.0              2.0           13.0

# %% [markdown]
# ## KEGG Enrichments

# %% [markdown]
# ### Load KEGG mapping
# The `kegg_mapping.csv` file contains KEGG orthologies, pathways, modules, and reactions. Only pathways and modules are relevant to iModulon characterization.

# %%
DF_KEGG = pd.read_csv(os.path.join('..','data','kegg_mapping.csv'),index_col=0)
print(DF_KEGG.database.unique())
DF_KEGG.head()
# Out:
# ['KEGG_Pathway' 'KEGG_Module' 'KEGG_Reaction']
#           gene_id      database   kegg_id
# 1878  WA5_RS00005  KEGG_Pathway  map02020
# 1879  WA5_RS00005  KEGG_Pathway  map04112
# 1886  WA5_RS00010  KEGG_Pathway  map00230
# 1887  WA5_RS00010  KEGG_Pathway  map00240
# 1888  WA5_RS00010  KEGG_Pathway  map01100

# %%
kegg_pathways = DF_KEGG[DF_KEGG.database == 'KEGG_Pathway']
kegg_modules = DF_KEGG[DF_KEGG.database == 'KEGG_Module']

# %%
print(kegg_pathways)
# Out:
#           gene_id      database   kegg_id
# 1878  WA5_RS00005  KEGG_Pathway  map02020
# 1879  WA5_RS00005  KEGG_Pathway  map04112
# 1886  WA5_RS00010  KEGG_Pathway  map00230
# 1887  WA5_RS00010  KEGG_Pathway  map00240
# 1888  WA5_RS00010  KEGG_Pathway  map01100
# ...           ...           ...       ...
# 8725  WA5_RS15490  KEGG_Pathway  map01503
# 8729  WA5_RS15515  KEGG_Pathway  map02024
# 8730  WA5_RS15515  KEGG_Pathway  map03060
# 8731  WA5_RS15515  KEGG_Pathway  map03070
# 8733  WA5_RS15525  KEGG_Pathway  map03010
#
# [3429 rows x 3 columns]

# %% [markdown]
# ### Perform enrichment
# Uses the `compute_annotation_enrichment` function

# %%
DF_pathway_enrich = ica_data.compute_annotation_enrichment(kegg_pathways,'kegg_id')
DF_module_enrich = ica_data.compute_annotation_enrichment(kegg_modules,'kegg_id')

# %%
DF_pathway_enrich
# Out:
#        imodulon   kegg_id        pvalue        qvalue  precision    recall  \
# 0   WA5_RS04335  map00910  4.177699e-04  9.441600e-02   0.096774  0.200000
# 1             4  map00791  1.393622e-04  1.574793e-02   0.095238  0.666667
# 2             4  map05120  1.393622e-04  1.574793e-02   0.095238  0.666667
# 3   WA5_RS09565  map02010  9.595278e-09  2.168533e-06   0.260000  0.120370
# 4   WA5_RS11920  map00362  6.627727e-13  9.974037e-11   0.636364  0.259259
# 5   WA5_RS11920  map01220  8.826582e-13  9.974037e-11   0.636364  0.250000
# 6   WA5_RS11920  map01120  9.380982e-07  7.067006e-05   0.636364  0.037037
# 7   WA5_RS11920  map00364  4.338704e-06  2.451368e-04   0.272727  0.300000
# 8   WA5_RS11920  map00624  1.221815e-05  5.522604e-04   0.181818  1.000000
# 9   WA5_RS11920  map00361  2.540247e-04  9.568265e-03   0.181818  0.285714
# 10  WA5_RS11920  map00623  4.337303e-04  1.400329e-02   0.181818  0.222222
# 11  WA5_RS11920  map01100  9.490386e-04  2.681034e-02   0.636364  0.013060
# 12  WA5_RS11920  map04013  3.665445e-03  8.283905e-02   0.090909  1.000000
# 13  WA5_RS11920  map05016  3.665445e-03  8.283905e-02   0.090909  1.000000
# 14  WA5_RS00825  map00562  1.876693e-07  4.241326e-05   0.192308  0.294118
# 15  WA5_RS03145  map01220  2.655943e-06  6.002430e-04   0.054945  0.357143
# 16  WA5_RS03145  map00362  1.649399e-05  1.863821e-03   0.049451  0.333333
# 17  WA5_RS03145  map00364  1.525664e-04  1.149334e-02   0.027473  0.500000
# 18           32  map00730  2.599994e-04  5.875986e-02   0.136364  0.166667
# 19           34  map00860  3.256971e-06  7.360754e-04   0.166667  0.200000
# 20           34  map00190  1.042216e-04  1.177704e-02   0.133333  0.153846
# 21  WA5_RS00045  map00920  6.271941e-07  1.417459e-04   0.307692  0.222222
# 22  WA5_RS14470  map00220  1.664496e-11  3.761761e-09   0.500000  0.333333
# 23  WA5_RS14470  map01230  8.198875e-08  9.264729e-06   0.583333  0.059322
# 24  WA5_RS14470  map01130  2.731642e-06  2.057837e-04   0.583333  0.035714
# 25  WA5_RS14470  map01110  1.450899e-05  8.197581e-04   0.583333  0.027888
# 26  WA5_RS14470  map01100  2.295766e-05  1.037686e-03   0.750000  0.016791
# 27  WA5_RS14470  map01210  9.437125e-05  3.554650e-03   0.250000  0.125000
# 28  WA5_RS14470  map00250  1.354599e-04  4.373421e-03   0.250000  0.111111
# 29           45  map03010  1.039314e-14  2.348850e-12   0.258621  0.283019
# 30           45  map00195  3.219911e-09  3.638500e-07   0.103448  0.666667
# 31           45  map00190  6.840138e-06  5.152904e-04   0.103448  0.230769
# 32           46  map00270  2.411409e-04  5.449785e-02   0.230769  0.100000
#
#      f1score    TP  target_set_size  imodulon_size
# 0   0.130435   3.0             15.0           31.0
# 1   0.166667   2.0              3.0           21.0
# 2   0.166667   2.0              3.0           21.0
# 3   0.164557  13.0            108.0           50.0
# 4   0.368421   7.0             27.0           11.0
# 5   0.358974   7.0             28.0           11.0
# 6   0.070000   7.0            189.0           11.0
# 7   0.285714   3.0             10.0           11.0
# 8   0.307692   2.0              2.0           11.0
# 9   0.222222   2.0              7.0           11.0
# 10  0.200000   2.0              9.0           11.0
# 11  0.025594   7.0            536.0           11.0
# 12  0.166667   1.0              1.0           11.0
# 13  0.166667   1.0              1.0           11.0
# 14  0.232558   5.0             17.0           26.0
# 15  0.095238  10.0             28.0          182.0
# 16  0.086124   9.0             27.0          182.0
# 17  0.052083   5.0             10.0          182.0
# 18  0.150000   3.0             18.0           22.0
# 19  0.181818   5.0             25.0           30.0
# 20  0.142857   4.0             26.0           30.0
# 21  0.258065   4.0             18.0           13.0
# 22  0.400000   6.0             18.0           12.0
# 23  0.107692   7.0            118.0           12.0
# 24  0.067308   7.0            196.0           12.0
# 25  0.053232   7.0            251.0           12.0
# 26  0.032847   9.0            536.0           12.0
# 27  0.166667   3.0             24.0           12.0
# 28  0.153846   3.0             27.0           12.0
# 29  0.270270  15.0             53.0           58.0
# 30  0.179104   6.0              9.0           58.0
# 31  0.142857   6.0             26.0           58.0
# 32  0.139535   3.0             30.0           13.0

# %%
DF_module_enrich
# Out:
#        imodulon kegg_id        pvalue        qvalue  precision    recall  \
# 0   WA5_RS04335  M00323  4.630973e-08  1.079017e-05   0.129032  0.800000
# 1             3  M00479  1.332889e-06  3.105631e-04   0.500000  1.000000
# 2   WA5_RS09565  M00240  1.030342e-15  2.400696e-13   0.260000  0.382353
# 3   WA5_RS11920  M00568  1.273089e-06  2.966297e-04   0.272727  0.428571
# 4            21  M00166  1.393622e-04  1.082380e-02   0.095238  0.666667
# 5            21  M00308  1.393622e-04  1.082380e-02   0.095238  0.666667
# 6            21  M00552  1.393622e-04  1.082380e-02   0.095238  0.666667
# 19  0.121212   2.0              3.0           30.0
# 20  0.300000   3.0              6.0           14.0
# 21  0.222222   2.0              4.0           14.0
# 22  0.375000   3.0              3.0           13.0
# 23  0.235294   2.0              4.0           13.0
# 24  0.400000   3.0              3.0           12.0
# 25  0.400000   3.0              3.0           12.0
# 26  0.375000   3.0              4.0           12.0
# 27  0.375000   3.0              4.0           12.0
# 28  0.210526   2.0              7.0           12.0
# 29  0.270270  15.0             53.0           58.0
# 30  0.269663  12.0             31.0           58.0
# 31  0.179104   6.0              9.0           58.0
# 32  0.266667   2.0              2.0           13.0
# 33  0.137931   2.0              2.0           27.0
# 34  0.571429   2.0              2.0            5.0

# %% [markdown]
# ### Convert KEGG IDs to human-readable names

# %%
for idx,key in tqdm(DF_pathway_enrich.kegg_id.items(),total=len(DF_pathway_enrich)):
    text = REST.kegg_find('pathway',key).read()
    try:
        name = re.search('\t(.*)\n',text).group(1)
        DF_pathway_enrich.loc[idx,'pathway_name'] = name
    except AttributeError:
        DF_pathway_enrich.loc[idx,'pathway_name'] = None
    
for idx,key in tqdm(DF_module_enrich.kegg_id.items(),total=len(DF_module_enrich)):
    text = REST.kegg_find('module',key).read()
    try:
        name = re.search('\t(.*)\n',text).group(1)
        DF_module_enrich.loc[idx,'module_name'] = name
    except AttributeError:
        DF_module_enrich.loc[idx,'module_name'] = None

# %%
DF_pathway_enrich
# Out:
#        imodulon   kegg_id        pvalue        qvalue  precision    recall  \
# 0   WA5_RS04335  map00910  4.177699e-04  9.441600e-02   0.096774  0.200000
# 1             4  map00791  1.393622e-04  1.574793e-02   0.095238  0.666667
# 2             4  map05120  1.393622e-04  1.574793e-02   0.095238  0.666667
# 3   WA5_RS09565  map02010  9.595278e-09  2.168533e-06   0.260000  0.120370
# 4   WA5_RS11920  map00362  6.627727e-13  9.974037e-11   0.636364  0.259259
# 5   WA5_RS11920  map01220  8.826582e-13  9.974037e-11   0.636364  0.250000
# 6   WA5_RS11920  map01120  9.380982e-07  7.067006e-05   0.636364  0.037037
# 7   WA5_RS11920  map00364  4.338704e-06  2.451368e-04   0.272727  0.300000
# 8   WA5_RS11920  map00624  1.221815e-05  5.522604e-04   0.181818  1.000000
# 9   WA5_RS11920  map00361  2.540247e-04  9.568265e-03   0.181818  0.285714
# 10  WA5_RS11920  map00623  4.337303e-04  1.400329e-02   0.181818  0.222222
# 11  WA5_RS11920  map01100  9.490386e-04  2.681034e-02   0.636364  0.013060
# 12  WA5_RS11920  map04013  3.665445e-03  8.283905e-02   0.090909  1.000000
# 13  WA5_RS11920  map05016  3.665445e-03  8.283905e-02   0.090909  1.000000
# 14  WA5_RS00825  map00562  1.876693e-07  4.241326e-05   0.192308  0.294118
# 15  WA5_RS03145  map01220  2.655943e-06  6.002430e-04   0.054945  0.357143
# 16  WA5_RS03145  map00362  1.649399e-05  1.863821e-03   0.049451  0.333333
# 17  WA5_RS03145  map00364  1.525664e-04  1.149334e-02   0.027473  0.500000
# 18           32  map00730  2.599994e-04  5.875986e-02   0.136364  0.166667
# 19           34  map00860  3.256971e-06  7.360754e-04   0.166667  0.200000
# 20           34  map00190  1.042216e-04  1.177704e-02   0.133333  0.153846
# 21  WA5_RS00045  map00920  6.271941e-07  1.417459e-04   0.307692  0.222222
# 22  WA5_RS14470  map00220  1.664496e-11  3.761761e-09   0.500000  0.333333
# 23  WA5_RS14470  map01230  8.198875e-08  9.264729e-06   0.583333  0.059322
# 24  WA5_RS14470  map01130  2.731642e-06  2.057837e-04   0.583333  0.035714
# 25  WA5_RS14470  map01110  1.450899e-05  8.197581e-04   0.583333  0.027888
# 26  WA5_RS14470  map01100  2.295766e-05  1.037686e-03   0.750000  0.016791
# 27  WA5_RS14470  map01210  9.437125e-05  3.554650e-03   0.250000  0.125000
# 28  WA5_RS14470  map00250  1.354599e-04  4.373421e-03   0.250000  0.111111
# 29           45  map03010  1.039314e-14  2.348850e-12   0.258621  0.283019
# 30           45  map00195  3.219911e-09  3.638500e-07   0.103448  0.666667
# 31           45  map00190  6.840138e-06  5.152904e-04   0.103448  0.230769
# 32           46  map00270  2.411409e-04  5.449785e-02   0.230769  0.100000
#
#      f1score    TP  target_set_size  imodulon_size  \
# 0   0.130435   3.0             15.0           31.0
# 1   0.166667   2.0              3.0           21.0
# 2   0.166667   2.0              3.0           21.0
# 3   0.164557  13.0            108.0           50.0
# 4   0.368421   7.0             27.0           11.0
# 5   0.358974   7.0             28.0           11.0
# 6   0.070000   7.0            189.0           11.0
# 7   0.285714   3.0             10.0           11.0
# 8   0.307692   2.0              2.0           11.0
# 9   0.222222   2.0              7.0           11.0
# 10  0.200000   2.0              9.0           11.0
# 11  0.025594   7.0            536.0           11.0
# 12  0.166667   1.0              1.0           11.0
# 13  0.166667   1.0              1.0           11.0
# 14  0.232558   5.0             17.0           26.0
# 15  0.095238  10.0             28.0          182.0
# 16  0.086124   9.0             27.0          182.0
# 17  0.052083   5.0             10.0          182.0
# 18  0.150000   3.0             18.0           22.0
# 19  0.181818   5.0             25.0           30.0
# 20  0.142857   4.0             26.0           30.0
# 21  0.258065   4.0             18.0           13.0
# 22  0.400000   6.0             18.0           12.0
# 23  0.107692   7.0            118.0           12.0
# 24  0.067308   7.0            196.0           12.0
# 25  0.053232   7.0            251.0           12.0
# 26  0.032847   9.0            536.0           12.0
# 27  0.166667   3.0             24.0           12.0
# 28  0.153846   3.0             27.0           12.0
# 29  0.270270  15.0             53.0           58.0
# 30  0.179104   6.0              9.0           58.0
# 31  0.142857   6.0             26.0           58.0
# 32  0.139535   3.0             30.0           13.0
#
#                                          pathway_name
# 0                                 Nitrogen metabolism
# 1                                Atrazine degradation
# 2   Epithelial cell signaling in Helicobacter pylo...
# 3                                    ABC transporters
# 4                                Benzoate degradation
# 5                   Degradation of aromatic compounds
# 6        Microbial metabolism in diverse environments
# 7                          Fluorobenzoate degradation
# 8         Polycyclic aromatic hydrocarbon degradation
# 9     Chlorocyclohexane and chlorobenzene degradation
# 10                                Toluene degradation
# 11                                 Metabolic pathways
# 12                       MAPK signaling pathway - fly
# 13                                 Huntington disease
# 14                      Inositol phosphate metabolism
# 15                  Degradation of aromatic compounds
# 30           45  M00179  8.795524e-14  1.024679e-11   0.206897  0.387097
# 31           45  M00157  3.219911e-09  2.500798e-07   0.103448  0.666667
# 32           46  M00021  1.732756e-05  4.037321e-03   0.153846  1.000000
# 33           47  M00479  7.797401e-05  1.816794e-02   0.074074  1.000000
# 34  WA5_RS01340  M00153  2.221482e-06  5.176052e-04   0.400000  1.000000
#
#      f1score    TP  target_set_size  imodulon_size  \
# 0   0.222222   4.0              5.0           31.0
# 1   0.666667   2.0              2.0            4.0
# 2   0.309524  13.0             34.0           50.0
# 3   0.333333   3.0              7.0           11.0
# 4   0.166667   2.0              3.0           21.0
# 5   0.166667   2.0              3.0           21.0
# 6   0.166667   2.0              3.0           21.0
# 7   0.157895   3.0             17.0           21.0
# 8   0.142857   2.0              7.0           21.0
# 9   0.133333   2.0              9.0           21.0
# 10  0.129032   2.0             10.0           21.0
# 11  0.043011   4.0              4.0          182.0
# 12  0.052356   5.0              9.0          182.0
# 13  0.032432   3.0              3.0          182.0
# 14  0.042328   4.0              7.0          182.0
# 15  0.032258   3.0              4.0          182.0
# 16  0.400000   2.0              5.0            5.0
# 17  0.206897   3.0              7.0           22.0
# 18  0.171429   3.0              5.0           30.0
# 19  0.121212   2.0              3.0           30.0
# 20  0.300000   3.0              6.0           14.0
# 21  0.222222   2.0              4.0           14.0
# 22  0.375000   3.0              3.0           13.0
# 23  0.235294   2.0              4.0           13.0
# 24  0.400000   3.0              3.0           12.0
# 25  0.400000   3.0              3.0           12.0
# 26  0.375000   3.0              4.0           12.0
# 27  0.375000   3.0              4.0           12.0
# 28  0.210526   2.0              7.0           12.0
# 29  0.270270  15.0             53.0           58.0
# 30  0.269663  12.0             31.0           58.0
# 31  0.179104   6.0              9.0           58.0
# 32  0.266667   2.0              2.0           13.0
# 33  0.137931   2.0              2.0           27.0
# 34  0.571429   2.0              2.0            5.0
#
#                                           module_name
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   Catechol ortho-cleavage, catechol => 3-oxoadipate
# 4   Reductive pentose phosphate cycle, ribulose-5P...
# 5   Semi-phosphorylative Entner-Doudoroff pathway,...
# 6   D-galactonate degradation, De Ley-Doudoroff pa...
# 7   Glycolysis (Embden-Meyerhof pathway), glucose ...
# 8    Reductive pentose phosphate cycle (Calvin cycle)
# 9   Glycolysis, core module involving three-carbon...
# 10       Gluconeogenesis, oxaloacetate => fructose-6P
# 11     Assimilatory sulfate reduction, sulfate => H2S
# 12                                               None
# 13                                               None
# 14  Catechol ortho-cleavage, catechol => 3-oxoadipate
# 15  Benzoate degradation, benzoate => catechol / m...
# 16  NAD biosynthesis, aspartate => quinolinate => NAD
# 17  Thiamine biosynthesis, prokaryotes, AIR (+ DXP...
# 18  Cobalamin biosynthesis, cobyrinate a,c-diamide...
# 19               Succinate dehydrogenase, prokaryotes
# 20                                               None
# 21     Assimilatory sulfate reduction, sulfate => H2S
# 22                                               None
# 23                                               None
# 24                                         Urea cycle
# 25       Arginine biosynthesis, ornithine => arginine
# 26     Ornithine biosynthesis, glutamate => ornithine
# 27  Arginine biosynthesis, glutamate => acetylcitr...
# 28  De novo pyrimidine biosynthesis, glutamine (+ ...
# 29                                               None
# 30                                               None
# 31        F-type ATPase, prokaryotes and chloroplasts
# 32          Cysteine biosynthesis, serine => cysteine
# 33                                               None
# 34                    Cytochrome bd ubiquinol oxidase

# %% [markdown]
# ## SubtiWiki categories

# %%
DF_subtiwiki = pd.read_csv(path.join(external_data,'subtiwiki_categories.csv'))
DF_subtiwiki.head()

# %%
# Change the subtiwiki annotation format into a list of genes and categories
DF_subtiwiki = DF_subtiwiki.rename({'BSU_number':'gene_id'},axis=1)
DF_subtiwiki = DF_subtiwiki.melt(id_vars='gene_id',value_vars=['FuncName1','FuncName2','FuncName3','FuncName4','FuncName5'])
DF_subtiwiki = DF_subtiwiki[DF_subtiwiki.value.notnull() & DF_subtiwiki.gene_id.isin(ica_data.gene_names)]
DF_subtiwiki.head()
# Out:
#      gene_id   variable               value
# 0  BSU_09670  FuncName1  Cellular processes
# 1  BSU_04560  FuncName1  Cellular processes
# 2  BSU_01770  FuncName1  Cellular processes
# 3  BSU_01780  FuncName1  Cellular processes
# 4  BSU_15190  FuncName1  Cellular processes

# %%
DF_subti_enrich = ica_data.compute_annotation_enrichment(DF_subtiwiki,'value')

# %% [markdown]
# ## Save files

# %%
DF_GO_enrich['source'] = 'GO'
# DF_pathway_enrich['source'] = 'KEGG pathways'
# DF_module_enrich['source'] = 'KEGG modules'
# DF_subti_enrich['source'] = 'SubtiWiki'

DF_GO_enrich.rename({'gene_ontology':'annotation'},axis=1, inplace=True)
# DF_pathway_enrich.rename({'kegg_id':'annotation'},axis=1, inplace=True)
# DF_module_enrich.rename({'kegg_id':'annotation'},axis=1, inplace=True)
# DF_subti_enrich.rename({'value':'annotation'},axis=1, inplace=True)

DF_enrichments = pd.concat([DF_GO_enrich, DF_pathway_enrich, DF_module_enrich])

# %% [markdown]
# # Check for single gene iModulons

# %% [markdown]
# Some iModulons are dominated by a single, high-coefficient gene. These iModulons may result from:
# 1. Overdecomposition of the dataset to identify noisy genes
# 1. Artificial knock-out of single genes
# 1. Regulons with only one target gene
#
# No matter what causes these iModulons, it is important to be aware of them. The find_single_gene_imodulons function identifies iModulons that are likely dominated by a single gene.
#
# The iModulons identified by ``find_single_gene_imodulons`` may contain more than one gene, since a threshold-agnostic method is used to identify these iModulons.

# %%
sg_imods = ica_data.find_single_gene_imodulons(save=True)
len(sg_imods)
# Out:
# 0

# %%
for i,mod in enumerate(sg_imods):
    ica_data.rename_imodulons({mod:'SG_'+str(i+1)})

# %% [markdown]
# # Save iModulon object

# %%
from pymodulon.util import explained_variance
from pymodulon.io import *

# %%
# Add iModulon sizes and explained variance
for im in ica_data.imodulon_names:
    ica_data.imodulon_table.loc[im,'imodulon_size'] = len(ica_data.view_imodulon(im))
    ica_data.imodulon_table.loc[im,'explained_variance'] = explained_variance(ica_data,imodulons=im)

# %% [markdown]
# This will save your iModulon table, your thresholds, and any other information stored in the ica_data object.

# %%
save_to_json(ica_data, os.path.join('..','data','cgu_raw.json.gz'))

# %% [markdown]
# If you prefer to view and edit your iModulon table in excel, save it as a CSV and reload the iModulon as before
