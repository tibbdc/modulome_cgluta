# %%
import numpy as np
from numpy import random
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pymodulon.io import *
from pymodulon.plotting import *
from os import path
import os
sns.set()

# %%
ica_data = load_json_model(os.path.join('..','data','cgu.json.gz'))

# %%
differ_growth_lackC = pd.read_csv(os.path.join('..','data','different_growth_rate_lackC.csv'),index_col=0)
flg = plt.figure(figsize=(8, 15))
sns_plot = sns.heatmap(differ_growth_lackC,cmap="RdBu_r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
differ_growth_lackN = pd.read_csv(os.path.join('..','data','different_growth_rate_lackN.csv'),index_col=0)
flg = plt.figure(figsize=(8, 15))
sns_plot = sns.heatmap(differ_growth_lackN,cmap="RdBu_r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
differ_growth_lackP = pd.read_csv(os.path.join('..','data','different_growth_rate_lackP.csv'),index_col=0)
flg = plt.figure(figsize=(8, 15))
sns_plot = sns.heatmap(differ_growth_lackP,cmap="RdBu_r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
differ_oxygen = pd.read_csv(os.path.join('..','data','different_oxygen.csv'),index_col=0)
flg = plt.figure(figsize=(8, 15))
sns_plot = sns.heatmap(differ_oxygen,cmap="RdBu_r")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
