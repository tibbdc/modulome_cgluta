# %%
from pymodulon.io import *
from pymodulon.plotting import *
from os import path
import os
import pandas as pd
pd.options.display.max_rows = None

# %%
data_dir = path.join('..','data')
interim_dir = path.join('..','data')

# %%
ica_data = load_json_model(os.path.join('..','data','cgu.json.gz'))

# %%
DF_enrichments = pd.read_csv(os.path.join('..','data','functional_enrichments.csv'),index_col=0)

# %% [markdown]
# Zur iModulon

# %%
ica_data.view_imodulon('Zur')
# Out:
#              gene_weight gene_name    accession old_locus_tag    start  \
# WA5_RS00150     0.394791    cg0040  NC_020519.1      WA5_0025    26819
# WA5_RS00155     0.462070      mntC  NC_020519.1      WA5_0026    28161
# WA5_RS00160     0.315112      mntB  NC_020519.1      WA5_0027    29114
# WA5_RS00165     0.214876      ZnuC  NC_020519.1      WA5_0028    29995
# WA5_RS03450     0.155730      yciC  NC_020519.1      WA5_0662   710516
# WA5_RS03455     0.088864    cg0795  NC_020519.1      WA5_0663   711723
# WA5_RS03460     0.168216      prpD  NC_020519.1      WA5_0664   712737
# WA5_RS03465     0.096039      prpB  NC_020519.1      WA5_0665   714230
# WA5_RS13220     0.276748    cg2918  NC_020519.1      WA5_2546  2804071
# WA5_RS13225     0.270542    cg2919  NC_020519.1      WA5_2547  2804673
# WA5_RS16570     0.214553    cg2920  NC_020519.1      WA5_2548  2805110
# WA5_RS16575     0.220372    cg2921  NC_020519.1      WA5_2549  2806013
#
# ...

# %%
plot_activities(ica_data,'Zur')
# Out:
# <AxesSubplot:ylabel='Zur iModulon\nActivity'>

# %%
DF_enrichments[DF_enrichments.imodulon=='Zur'].sort_values('f1score',ascending=False)
# Out:
# Empty DataFrame
# Columns: [imodulon, annotation, pvalue, qvalue, precision, recall, f1score, TP, target_set_size, imodulon_size, source, kegg_id, pathway_name, module_name]
# Index: []

# %% [markdown]
# SufR iModulon

# %%
ica_data.view_imodulon('SufR')
# Out:
#              gene_weight gene_name    accession old_locus_tag    start  \
# WA5_RS07795     0.190451      sufS  NC_020519.1      WA5_1500  1648096
# WA5_RS07800     0.228565      sufC  NC_020519.1      WA5_1501  1649363
# WA5_RS07805     0.278019      sufD  NC_020519.1      WA5_1502  1650245
# WA5_RS07810     0.278535      sufB  NC_020519.1      WA5_1503  1651429
# WA5_RS07815     0.264523      sufR  NC_020519.1      WA5_1504  1652890
# WA5_RS07820     0.240989      mptB  NC_020519.1      WA5_1505  1653898
#
#                  end strand  \
# WA5_RS07795  1649361      -
# WA5_RS07800  1650121      -
# WA5_RS07805  1651423      -
# WA5_RS07810  1652874      -
# WA5_RS07815  1653576      -
# WA5_RS07820  1655673      +
#
#                                                   gene_product  \
# WA5_RS07795                               cysteine desulfurase
# WA5_RS07800                  Fe-S cluster assembly ATPase SufC
# WA5_RS07805                 Fe-S cluster assembly protein SufD
# ...

# %%
plot_activities(ica_data,'SufR')
# Out:
# <AxesSubplot:ylabel='SufR iModulon\nActivity'>

# %%
DF_enrichments[DF_enrichments.imodulon=='SufR'].sort_values('f1score',ascending=False)
# Out:
# Empty DataFrame
# Columns: [imodulon, annotation, pvalue, qvalue, precision, recall, f1score, TP, target_set_size, imodulon_size, source, kegg_id, pathway_name, module_name]
# Index: []

# %% [markdown]
# ArgR iModulon

# %%
ica_data.view_imodulon('ArgR')
# Out:
#              gene_weight gene_name    accession old_locus_tag    start  \
# WA5_RS06955     0.150061      argJ  NC_020519.1      WA5_1341  1465209
# WA5_RS06960     0.315476      argB  NC_020519.1      WA5_1342  1466421
# WA5_RS06965     0.307693      argD  NC_020519.1      WA5_1343  1467375
# WA5_RS06970     0.307280      argF  NC_020519.1      WA5_1344  1468564
# WA5_RS06975     0.306717      argR  NC_020519.1      WA5_1345  1469527
# WA5_RS06980     0.226408      argG  NC_020519.1      WA5_1346  1470210
# WA5_RS06985     0.152635      argH  NC_020519.1      WA5_1347  1471476
# WA5_RS06990     0.154729    cg1589  NC_020519.1      WA5_1348  1472976
# WA5_RS06995     0.114630    cg1590  NC_020519.1      WA5_1349  1474118
# WA5_RS08035     0.155642      carA  NC_020519.1      WA5_1548  1707702
# WA5_RS08040     0.147625      pyrC  NC_020519.1      WA5_1549  1709013
# WA5_RS08045     0.110442      pyrB  NC_020519.1      WA5_1550  1710409
#
#                  end strand  \
# ...

# %%
plot_activities(ica_data,'ArgR')
# Out:
# <AxesSubplot:ylabel='ArgR iModulon\nActivity'>

# %%
DF_enrichments[DF_enrichments.imodulon=='ArgR'].sort_values('f1score',ascending=False)
# Out:
# Empty DataFrame
# Columns: [imodulon, annotation, pvalue, qvalue, precision, recall, f1score, TP, target_set_size, imodulon_size, source, kegg_id, pathway_name, module_name]
# Index: []

# %%
save_to_json(ica_data, path.join(data_dir, 'cgu.json.gz'))

# %%
ica_data.imodulon_table.to_csv(path.join(data_dir, 'imodulon_table.csv'))
